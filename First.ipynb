# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-dulariya/CodSoft_Landing_page/blob/main/First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Just Beginner Things

# %%
print("Mahakaal")
# Out:
# Mahakaal

# %% [markdown]
# python Libraries use kar sakte h

# %%
A = 3
B = 4
C = A*B
C
# Out:
# 12

# %% [markdown]
# Ram
